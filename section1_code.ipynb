# %%
 import os
import re  # Import regex for better filename extraction
import numpy as np
import csv

def pgm_to_csv(pgm_file, csv_file, threshold=128):
    with open(pgm_file, 'r') as f:
        lines = f.readlines()
    
    # Extract pixel values (skip the header)
    pixel_values = []
    for line in lines[4:]:  # Skip first 4 header lines
        pixel_values.extend(map(int, line.split()))
    
    # Convert to 18x18 numpy array
    image_matrix = np.array(pixel_values).reshape(18, 18)
    
    # Apply threshold (black = 1, white = 0)
    binary_matrix = (image_matrix < threshold).astype(int)
    
    # Save as CSV (comma-separated, no header)
    with open(csv_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerows(binary_matrix)

def batch_convert_pgm_to_csv(input_dir, student_number):
    if not os.path.exists(input_dir):
        print(f"Input directory {input_dir} does not exist.")
        return
    
    for filename in os.listdir(input_dir):
        if filename.endswith('.pgm'):
            name_parts = filename[:-4]  # Remove ".pgm"
            
            # Extract label and index using regex (matches letters + digits at the end)
            match = re.match(r"([a-zA-Z]+)_?(\d+)$", name_parts)
            if match:
                label, index = match.groups()
                index = index.zfill(2)  # Ensure the index is always two digits (e.g., "07")
                
                csv_filename = f"{student_number}_{label}_{index}.csv"
                pgm_to_csv(os.path.join(input_dir, filename), os.path.join(input_dir, csv_filename))
                print(f"Converted {filename} -> {csv_filename}")
            else:
                print(f"Skipping {filename} - Filename format is incorrect.")

# Example usage
STUDENT_NUMBER = "40415474"  # Replace with your actual student number
INPUT_DIR = "images"  # Folder containing .pgm files (and where CSV files will be saved)

batch_convert_pgm_to_csv(INPUT_DIR, STUDENT_NUMBER)
# Out:
# Converted i2.pgm -> 40415474_i_02.csv
# Converted h6.pgm -> 40415474_h_06.csv
# Converted sad3.pgm -> 40415474_sad_03.csv
# Converted e1.pgm -> 40415474_e_01.csv
# Converted d5.pgm -> 40415474_d_05.csv
# Converted g8.pgm -> 40415474_g_08.csv
# Converted d4.pgm -> 40415474_d_04.csv
# Converted sad2.pgm -> 40415474_sad_02.csv
# Converted h7.pgm -> 40415474_h_07.csv
# Converted i3.pgm -> 40415474_i_03.csv
# Converted h5.pgm -> 40415474_h_05.csv
# Converted i1.pgm -> 40415474_i_01.csv
# Converted d6.pgm -> 40415474_d_06.csv
# Converted e2.pgm -> 40415474_e_02.csv
# Converted e3.pgm -> 40415474_e_03.csv
# Converted d7.pgm -> 40415474_d_07.csv
# Converted sad1.pgm -> 40415474_sad_01.csv
# Converted h4.pgm -> 40415474_h_04.csv
# Converted sad5.pgm -> 40415474_sad_05.csv
# Converted j8.pgm -> 40415474_j_08.csv
# Converted i4.pgm -> 40415474_i_04.csv
# Converted d3.pgm -> 40415474_d_03.csv
# Converted e7.pgm -> 40415474_e_07.csv
# Converted e6.pgm -> 40415474_e_06.csv
# Converted d2.pgm -> 40415474_d_02.csv
# Converted i5.pgm -> 40415474_i_05.csv
# Converted h1.pgm -> 40415474_h_01.csv
# Converted sad4.pgm -> 40415474_sad_04.csv
# Converted sad6.pgm -> 40415474_sad_06.csv
# Converted i7.pgm -> 40415474_i_07.csv
# Converted h3.pgm -> 40415474_h_03.csv
# Converted f8.pgm -> 40415474_f_08.csv
# Converted e4.pgm -> 40415474_e_04.csv
# Converted d1.pgm -> 40415474_d_01.csv
# Converted e5.pgm -> 40415474_e_05.csv
# Converted h2.pgm -> 40415474_h_02.csv
# Converted i6.pgm -> 40415474_i_06.csv
# Converted sad7.pgm -> 40415474_sad_07.csv
# Converted xclaim14.pgm -> 40415474_xclaim_14.csv
# Converted c2.pgm -> 40415474_c_02.csv
# Converted smile5.pgm -> 40415474_smile_05.csv
# Converted b6.pgm -> 40415474_b_06.csv
# Converted sad18.pgm -> 40415474_sad_18.csv
# Converted sad19.pgm -> 40415474_sad_19.csv
# Converted smile4.pgm -> 40415474_smile_04.csv
# Converted b7.pgm -> 40415474_b_07.csv
# Converted c3.pgm -> 40415474_c_03.csv
# Converted xclaim15.pgm -> 40415474_xclaim_15.csv
# Converted xclaim17.pgm -> 40415474_xclaim_17.csv
# Converted xclaim9.pgm -> 40415474_xclaim_09.csv
# Converted b5.pgm -> 40415474_b_05.csv
# Converted smile6.pgm -> 40415474_smile_06.csv
# Converted c1.pgm -> 40415474_c_01.csv
# Converted smile18.pgm -> 40415474_smile_18.csv
# Converted smile19.pgm -> 40415474_smile_19.csv
# Converted a8.pgm -> 40415474_a_08.csv
# Converted b4.pgm -> 40415474_b_04.csv
# Converted smile7.pgm -> 40415474_smile_07.csv
# Converted xclaim8.pgm -> 40415474_xclaim_08.csv
# Converted xclaim16.pgm -> 40415474_xclaim_16.csv
# Converted xclaim12.pgm -> 40415474_xclaim_12.csv
# Converted smile3.pgm -> 40415474_smile_03.csv
# Converted c4.pgm -> 40415474_c_04.csv
# Converted smile20.pgm -> 40415474_smile_20.csv
# Converted c5.pgm -> 40415474_c_05.csv
# Converted smile2.pgm -> 40415474_smile_02.csv
# Converted b1.pgm -> 40415474_b_01.csv
# Converted xclaim13.pgm -> 40415474_xclaim_13.csv
# Converted xclaim11.pgm -> 40415474_xclaim_11.csv
# Converted c7.pgm -> 40415474_c_07.csv
# Converted b3.pgm -> 40415474_b_03.csv
# Converted b2.pgm -> 40415474_b_02.csv
# Converted smile1.pgm -> 40415474_smile_01.csv
# Converted sad20.pgm -> 40415474_sad_20.csv
# Converted c6.pgm -> 40415474_c_06.csv
# Converted xclaim10.pgm -> 40415474_xclaim_10.csv
# Converted xclaim3.pgm -> 40415474_xclaim_03.csv
# Converted a3.pgm -> 40415474_a_03.csv
# Converted sad11.pgm -> 40415474_sad_11.csv
# Converted smile12.pgm -> 40415474_smile_12.csv
# Converted smile13.pgm -> 40415474_smile_13.csv
# Converted a2.pgm -> 40415474_a_02.csv
# Converted sad10.pgm -> 40415474_sad_10.csv
# Converted xclaim2.pgm -> 40415474_xclaim_02.csv
# Converted xclaim20.pgm -> 40415474_xclaim_20.csv
# Converted sad12.pgm -> 40415474_sad_12.csv
# Converted c8.pgm -> 40415474_c_08.csv
# Converted smile11.pgm -> 40415474_smile_11.csv
# Converted smile10.pgm -> 40415474_smile_10.csv
# Converted sad13.pgm -> 40415474_sad_13.csv
# Converted a1.pgm -> 40415474_a_01.csv
# Converted xclaim1.pgm -> 40415474_xclaim_01.csv
# Converted xclaim5.pgm -> 40415474_xclaim_05.csv
# Converted a5.pgm -> 40415474_a_05.csv
# Converted sad17.pgm -> 40415474_sad_17.csv
# Converted smile14.pgm -> 40415474_smile_14.csv
# Converted smile15.pgm -> 40415474_smile_15.csv
# Converted a4.pgm -> 40415474_a_04.csv
# Converted sad16.pgm -> 40415474_sad_16.csv
# Converted b8.pgm -> 40415474_b_08.csv
# Converted xclaim4.pgm -> 40415474_xclaim_04.csv
# Converted xclaim18.pgm -> 40415474_xclaim_18.csv
# Converted xclaim6.pgm -> 40415474_xclaim_06.csv
# Converted smile9.pgm -> 40415474_smile_09.csv
# Converted sad14.pgm -> 40415474_sad_14.csv
# Converted a6.pgm -> 40415474_a_06.csv
# Converted smile17.pgm -> 40415474_smile_17.csv
# Converted smile16.pgm -> 40415474_smile_16.csv
# Converted sad15.pgm -> 40415474_sad_15.csv
# Converted a7.pgm -> 40415474_a_07.csv
# Converted smile8.pgm -> 40415474_smile_08.csv
# Converted xclaim7.pgm -> 40415474_xclaim_07.csv
# Converted xclaim19.pgm -> 40415474_xclaim_19.csv
# Converted j7.pgm -> 40415474_j_07.csv
# Converted f4.pgm -> 40415474_f_04.csv
# Converted e8.pgm -> 40415474_e_08.csv
# Converted f5.pgm -> 40415474_f_05.csv
# Converted g1.pgm -> 40415474_g_01.csv
# Converted j6.pgm -> 40415474_j_06.csv
# Converted j4.pgm -> 40415474_j_04.csv
# Converted sad9.pgm -> 40415474_sad_09.csv
# Converted i8.pgm -> 40415474_i_08.csv
# Converted f7.pgm -> 40415474_f_07.csv
# Converted g3.pgm -> 40415474_g_03.csv
# Converted g2.pgm -> 40415474_g_02.csv
# Converted f6.pgm -> 40415474_f_06.csv
# Converted sad8.pgm -> 40415474_sad_08.csv
# Converted j5.pgm -> 40415474_j_05.csv
# Converted j1.pgm -> 40415474_j_01.csv
# Converted f2.pgm -> 40415474_f_02.csv
# Converted g6.pgm -> 40415474_g_06.csv
# Converted g7.pgm -> 40415474_g_07.csv
# Converted f3.pgm -> 40415474_f_03.csv
# Converted h8.pgm -> 40415474_h_08.csv
# Converted j2.pgm -> 40415474_j_02.csv
# Converted g5.pgm -> 40415474_g_05.csv
# Converted f1.pgm -> 40415474_f_01.csv
# Converted g4.pgm -> 40415474_g_04.csv
# Converted d8.pgm -> 40415474_d_08.csv
# Converted j3.pgm -> 40415474_j_03.csv
